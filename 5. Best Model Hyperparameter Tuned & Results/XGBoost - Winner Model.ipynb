# %% [markdown]
# Train the winner model:
#
# Use the XGBRegressor algorithm to train a regression model on the training data. XGBoost is a popular gradient boosting algorithm that can handle regression tasks effectively.
#
# Make sure to set appropriate hyperparameters, such as the learning rate, number of estimators, and maximum depth, to optimize the model's performance.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, r2_score

imputed_data = pd.read_csv("imputed_data_handle_multicollinearity.csv")

# Prepare the data
X = imputed_data[['OverallQual', 'GrLivArea', 'TotalBsmtSF', '1stFlrSF', 'GarageArea',    
                   'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtUnfSF', 'Fireplaces',
                  'Neighborhood_Blueste', 'Neighborhood_BrDale', 'Neighborhood_BrkSide', 
                  'Neighborhood_ClearCr', 'Neighborhood_CollgCr', 'Neighborhood_Crawfor', 
                  'Neighborhood_Edwards', 'Neighborhood_Gilbert', 'Neighborhood_Greens', 
                  'Neighborhood_GrnHill', 'Neighborhood_IDOTRR', 'Neighborhood_Landmrk', 
                  'Neighborhood_MeadowV', 'Neighborhood_Mitchel', 'Neighborhood_NAmes', 
                  'Neighborhood_NPkVill', 'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 
                  'Neighborhood_NridgHt', 'Neighborhood_OldTown', 'Neighborhood_SWISU', 
                  'Neighborhood_Sawyer', 'Neighborhood_SawyerW', 'Neighborhood_Somerst', 
                  'Neighborhood_StoneBr', 'Neighborhood_Timber', 'Neighborhood_Veenker']]

y = imputed_data['SalePrice']

# Create an instance of XGBRegressor
xgb = XGBRegressor()

# Define the number of folds for cross-validation
num_folds = 5

# Define the cross-validation strategy
cv = KFold(n_splits=num_folds, shuffle=True)

# Define the hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 0.01, 0.001],
    'max_depth': [3, 4, 5]
}

# Perform grid search
grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=cv, scoring='neg_mean_absolute_error')
grid_search.fit(X, y)

# Print the best hyperparameters and the corresponding mean score
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Mean MAE:", -grid_search.best_score_)

# List of all neighborhood columns
neighborhood_cols = ['Neighborhood_Blueste', 'Neighborhood_BrDale', 'Neighborhood_BrkSide', 
                     'Neighborhood_ClearCr', 'Neighborhood_CollgCr', 'Neighborhood_Crawfor', 
                     'Neighborhood_Edwards', 'Neighborhood_Gilbert', 'Neighborhood_Greens', 
                     'Neighborhood_GrnHill', 'Neighborhood_IDOTRR', 'Neighborhood_Landmrk', 
                     'Neighborhood_MeadowV', 'Neighborhood_Mitchel', 'Neighborhood_NAmes', 
                     'Neighborhood_NPkVill', 'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 
                     'Neighborhood_NridgHt', 'Neighborhood_OldTown', 'Neighborhood_SWISU', 
                     'Neighborhood_Sawyer', 'Neighborhood_SawyerW', 'Neighborhood_Somerst', 
                     'Neighborhood_StoneBr', 'Neighborhood_Timber', 'Neighborhood_Veenker']

# Create 'Neighborhood' DataFrame
neighborhood = X[neighborhood_cols].idxmax(axis=1)
neighborhood = neighborhood.str.replace('Neighborhood_', '')

# Split the data into train and test sets along with 'Neighborhood' DataFrame
X_train, X_test, y_train, y_test, neighborhood_train, neighborhood_test = train_test_split(
    X, y, neighborhood, test_size=0.3)

# Fit the model on the training data using the best hyperparameters
xgb_best = XGBRegressor(**grid_search.best_params_)
xgb_best.fit(X_train, y_train)

# Make predictions on the test set
y_pred_test = xgb_best.predict(X_test)

# Evaluate the model
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)

print("MAE Test:", mae_test)
print("R^2 Test:", r2_test)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300}
# Best Mean MAE: 5487.087436409884
# MAE Test: 6557.530848776647
# R^2 Test: 0.9829312430282665

# %% [markdown]
# Calculate residuals: The code does not explicitly calculate residuals. Residuals represent the differences between the predicted sale prices and the actual sale prices. To calculate residuals, you can subtract the predicted sale prices (y_pred_test) from the actual sale prices (y_test).
#
# Identify undervalued properties: Sorting the properties based on residuals to identify undervalued properties is not covered in the provided code. To identify undervalued properties, you would need to sort the properties in the test set based on their residuals in ascending order.
#
# Analyze undervalued properties: Analyzing undervalued properties for potential reasons for their underpricing is not covered in the provided code. This step involves examining the properties with low residuals and considering factors that might have been overlooked in the model, such as unique features, renovations, location advantages, or upcoming developments.

# %%
# Calculate residuals
residuals = y_pred_test - y_test

# Create a DataFrame with residuals, actual sale prices, predicted sale prices, and neighborhoods
residuals_df = pd.DataFrame({
    'Actual Sale Price': y_test, 
    'Predicted Sale Price': y_pred_test, 
    'Residuals': residuals, 
    'Neighborhood': neighborhood_test 
})

# Filter undervalued properties
undervalued_properties = residuals_df[residuals_df['Actual Sale Price'] < residuals_df['Predicted Sale Price']].sort_values(by='Residuals', ascending=False)

# Print the undervalued properties with neighborhoods
print("Undervalued Properties:")
top_undervalued_properties = undervalued_properties
for index, row in top_undervalued_properties.iterrows():
    print("Property Neighborhood:", row['Neighborhood'])
    print("Actual Sale Price:", row['Actual Sale Price'])
    print("Predicted Sale Price:", row['Predicted Sale Price'])
    print("Residual:", row['Residuals'])
    print()
# Out:
# Undervalued Properties:
# Property Neighborhood: Somerst
# Actual Sale Price: 260116.0
# Predicted Sale Price: 327122.5625
# Residual: 67006.5625
#
# Property Neighborhood: Timber
# Actual Sale Price: 327000.0
# Predicted Sale Price: 392312.1875
# Residual: 65312.1875
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 110000.0
# Predicted Sale Price: 146002.09375
# Residual: 36002.09375
#
# Property Neighborhood: OldTown
# Actual Sale Price: 221300.0
# Predicted Sale Price: 255930.515625
# Residual: 34630.515625
#
# Property Neighborhood: Edwards
# Actual Sale Price: 221300.0
# Predicted Sale Price: 255460.65625
# Residual: 34160.65625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 97500.0
# Predicted Sale Price: 131128.28125
# Residual: 33628.28125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 97500.0
# Predicted Sale Price: 130784.9375
# Residual: 33284.9375
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 97500.0
# Predicted Sale Price: 130245.5078125
# Residual: 32745.5078125
#
# Property Neighborhood: Veenker
# Actual Sale Price: 221300.0
# Predicted Sale Price: 252649.9375
# Residual: 31349.9375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 171000.0
# Predicted Sale Price: 198623.4375
# Residual: 27623.4375
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 82500.0
# Predicted Sale Price: 109908.8984375
# Residual: 27408.8984375
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 82500.0
# Predicted Sale Price: 109908.8984375
# Residual: 27408.8984375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 150000.0
# Predicted Sale Price: 176754.078125
# Residual: 26754.078125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 166000.0
# Predicted Sale Price: 191446.109375
# Residual: 25446.109375
#
# Property Neighborhood: OldTown
# Actual Sale Price: 159000.0
# Predicted Sale Price: 184024.078125
# Residual: 25024.078125
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 159000.0
# Predicted Sale Price: 183227.984375
# Residual: 24227.984375
#
# Property Neighborhood: Somerst
# Actual Sale Price: 159000.0
# Predicted Sale Price: 182894.296875
# Residual: 23894.296875
#
# Property Neighborhood: NridgHt
# Actual Sale Price: 133000.0
# Predicted Sale Price: 156316.296875
# Residual: 23316.296875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 105000.0
# Predicted Sale Price: 127038.4140625
# Residual: 22038.4140625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 108538.0
# Predicted Sale Price: 130413.0
# Residual: 21875.0
#
# Property Neighborhood: NAmes
# Actual Sale Price: 108538.0
# Predicted Sale Price: 130292.953125
# Residual: 21754.953125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 200000.0
# Predicted Sale Price: 221577.625
# Residual: 21577.625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 140000.0
# Predicted Sale Price: 161181.609375
# Residual: 21181.609375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 140000.0
# Predicted Sale Price: 161174.671875
# Residual: 21174.671875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 220000.0
# Predicted Sale Price: 240818.46875
# Residual: 20818.46875
#
# Property Neighborhood: OldTown
# Actual Sale Price: 76500.0
# Predicted Sale Price: 97232.0703125
# Residual: 20732.0703125
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 220000.0
# Predicted Sale Price: 240660.4375
# Residual: 20660.4375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 220000.0
# Predicted Sale Price: 240380.171875
# Residual: 20380.171875
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 200000.0
# Predicted Sale Price: 220187.484375
# Residual: 20187.484375
#
# Property Neighborhood: Somerst
# Actual Sale Price: 200000.0
# Predicted Sale Price: 219058.546875
# Residual: 19058.546875
#
# Property Neighborhood: Somerst
# Actual Sale Price: 50000.0
# Predicted Sale Price: 67850.6171875
# Residual: 17850.6171875
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 146500.0
# Predicted Sale Price: 162687.03125
# Residual: 16187.03125
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 120875.0
# Predicted Sale Price: 136983.34375
# Residual: 16108.34375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 61500.0
# Predicted Sale Price: 77366.40625
# Residual: 15866.40625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 75200.0
# Predicted Sale Price: 90877.375
# Residual: 15677.375
#
# Property Neighborhood: StoneBr
# Actual Sale Price: 123000.0
# Predicted Sale Price: 138615.125
# Residual: 15615.125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 123000.0
# Predicted Sale Price: 138523.59375
# Residual: 15523.59375
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 113000.0
# Predicted Sale Price: 128516.1171875
# Residual: 15516.1171875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 200000.0
# Predicted Sale Price: 215246.140625
# Residual: 15246.140625
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 93850.0
# Predicted Sale Price: 108946.28125
# Residual: 15096.28125
#
# Property Neighborhood: NridgHt
# Actual Sale Price: 200000.0
# Predicted Sale Price: 214969.53125
# Residual: 14969.53125
#
# Property Neighborhood: Somerst
# Actual Sale Price: 123000.0
# Predicted Sale Price: 137745.578125
# Residual: 14745.578125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 212999.0
# Predicted Sale Price: 227484.28125
# Residual: 14485.28125
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 34900.0
# Predicted Sale Price: 48856.0390625
# Residual: 13956.0390625
#
# Property Neighborhood: OldTown
# Actual Sale Price: 90000.0
# Predicted Sale Price: 103950.0390625
# Residual: 13950.0390625
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 75200.0
# Predicted Sale Price: 89080.8203125
# Residual: 13880.8203125
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 195000.0
# Predicted Sale Price: 208625.296875
# Residual: 13625.296875
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 195000.0
# Predicted Sale Price: 208625.296875
# Residual: 13625.296875
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 180000.0
# Predicted Sale Price: 193571.328125
# Residual: 13571.328125
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 34900.0
# Predicted Sale Price: 48429.7109375
# Residual: 13529.7109375
#
# Property Neighborhood: Edwards
# Actual Sale Price: 130000.0
# Predicted Sale Price: 143096.75
# Residual: 13096.75
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 120000.0
# Predicted Sale Price: 132707.484375
# Residual: 12707.484375
#
# Property Neighborhood: NoRidge
# Actual Sale Price: 135000.0
# Predicted Sale Price: 147584.0
# Residual: 12584.0
#
# Property Neighborhood: NPkVill
# Actual Sale Price: 212500.0
# Predicted Sale Price: 224902.71875
# Residual: 12402.71875
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 129000.0
# Predicted Sale Price: 140850.828125
# Residual: 11850.828125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 81000.00000000001
# Predicted Sale Price: 92587.7734375
# Residual: 11587.773437499985
#
# Property Neighborhood: SWISU
# Actual Sale Price: 12789.0
# Predicted Sale Price: 24325.458984375
# Residual: 11536.458984375
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 135000.0
# Predicted Sale Price: 146382.15625
# Residual: 11382.15625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 12789.0
# Predicted Sale Price: 24091.765625
# Residual: 11302.765625
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 90000.0
# Predicted Sale Price: 100864.4140625
# Residual: 10864.4140625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 130000.0
# Predicted Sale Price: 140342.953125
# Residual: 10342.953125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 119500.0
# Predicted Sale Price: 129826.625
# Residual: 10326.625
#
# Property Neighborhood: Somerst
# Actual Sale Price: 78999.99999999999
# Predicted Sale Price: 89320.734375
# Residual: 10320.734375000015
#
# Property Neighborhood: NAmes
# Actual Sale Price: 155000.0
# Predicted Sale Price: 165320.234375
# Residual: 10320.234375
#
# Property Neighborhood: Edwards
# Actual Sale Price: 194000.0
# Predicted Sale Price: 204252.484375
# Residual: 10252.484375
#
# Property Neighborhood: Timber
# Actual Sale Price: 117000.0
# Predicted Sale Price: 127177.6875
# Residual: 10177.6875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 258000.0
# Predicted Sale Price: 268151.78125
# Residual: 10151.78125
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 158000.0
# Predicted Sale Price: 168059.8125
# Residual: 10059.8125
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 81300.0
# Predicted Sale Price: 91341.59375
# Residual: 10041.59375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 79500.0
# Predicted Sale Price: 89448.21875
# Residual: 9948.21875
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 168000.0
# Predicted Sale Price: 177938.359375
# Residual: 9938.359375
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 258000.0
# Predicted Sale Price: 267909.59375
# Residual: 9909.59375
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 152000.0
# Predicted Sale Price: 161752.953125
# Residual: 9752.953125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 163000.0
# Predicted Sale Price: 172604.1875
# Residual: 9604.1875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 115000.0
# Predicted Sale Price: 124407.1640625
# Residual: 9407.1640625
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 192000.0
# Predicted Sale Price: 201393.15625
# Residual: 9393.15625
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 235000.0
# Predicted Sale Price: 244373.953125
# Residual: 9373.953125
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 168000.0
# Predicted Sale Price: 177069.640625
# Residual: 9069.640625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 290000.0
# Predicted Sale Price: 298964.5
# Residual: 8964.5
#
# Property Neighborhood: NAmes
# Actual Sale Price: 290000.0
# Predicted Sale Price: 298964.5
# Residual: 8964.5
#
# Property Neighborhood: NAmes
# Actual Sale Price: 138000.0
# Predicted Sale Price: 146806.265625
# Residual: 8806.265625
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 169000.0
# Predicted Sale Price: 177683.90625
# Residual: 8683.90625
#
# Property Neighborhood: Edwards
# Actual Sale Price: 192000.0
# Predicted Sale Price: 200622.1875
# Residual: 8622.1875
#
# Property Neighborhood: Timber
# Actual Sale Price: 138000.0
# Predicted Sale Price: 146564.046875
# Residual: 8564.046875
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 159000.0
# Predicted Sale Price: 167551.015625
# Residual: 8551.015625
#
# Property Neighborhood: OldTown
# Actual Sale Price: 169000.0
# Predicted Sale Price: 177503.546875
# Residual: 8503.546875
#
# Property Neighborhood: NoRidge
# Actual Sale Price: 149500.0
# Predicted Sale Price: 157943.75
# Residual: 8443.75
#
# Property Neighborhood: SWISU
# Actual Sale Price: 175000.0
# Predicted Sale Price: 183259.9375
# Residual: 8259.9375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 148000.0
# Predicted Sale Price: 156249.703125
# Residual: 8249.703125
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 140000.0
# Predicted Sale Price: 148241.34375
# Residual: 8241.34375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 112000.0
# Predicted Sale Price: 120223.4140625
# Residual: 8223.4140625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 286000.0
# Predicted Sale Price: 294191.21875
# Residual: 8191.21875
#
# Property Neighborhood: Somerst
# Actual Sale Price: 158000.0
# Predicted Sale Price: 166184.375
# Residual: 8184.375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 137900.0
# Predicted Sale Price: 146066.640625
# Residual: 8166.640625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 110000.0
# Predicted Sale Price: 118093.09375
# Residual: 8093.09375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 235000.0
# Predicted Sale Price: 243054.265625
# Residual: 8054.265625
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 137900.0
# Predicted Sale Price: 145926.859375
# Residual: 8026.859375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 190000.0
# Predicted Sale Price: 197960.796875
# Residual: 7960.796875
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 123000.0
# Predicted Sale Price: 130939.765625
# Residual: 7939.765625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 183500.0
# Predicted Sale Price: 191419.03125
# Residual: 7919.03125
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 212500.0
# Predicted Sale Price: 220347.796875
# Residual: 7847.796875
#
# Property Neighborhood: BrDale
# Actual Sale Price: 135000.0
# Predicted Sale Price: 142804.015625
# Residual: 7804.015625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 193500.0
# Predicted Sale Price: 201301.484375
# Residual: 7801.484375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 140000.0
# Predicted Sale Price: 147767.28125
# Residual: 7767.28125
#
# Property Neighborhood: SWISU
# Actual Sale Price: 112000.0
# Predicted Sale Price: 119724.3203125
# Residual: 7724.3203125
#
# Property Neighborhood: BrDale
# Actual Sale Price: 168000.0
# Predicted Sale Price: 175629.203125
# Residual: 7629.203125
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 140000.0
# Predicted Sale Price: 147527.8125
# Residual: 7527.8125
#
# Property Neighborhood: Timber
# Actual Sale Price: 140000.0
# Predicted Sale Price: 147525.0625
# Residual: 7525.0625
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 95000.0
# Predicted Sale Price: 102371.6015625
# Residual: 7371.6015625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 99500.0
# Predicted Sale Price: 106775.484375
# Residual: 7275.484375
#
# Property Neighborhood: Somerst
# Actual Sale Price: 119500.0
# Predicted Sale Price: 126740.28125
# Residual: 7240.28125
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 185850.0
# Predicted Sale Price: 193058.046875
# Residual: 7208.046875
#
# Property Neighborhood: Edwards
# Actual Sale Price: 78000.0
# Predicted Sale Price: 85206.6015625
# Residual: 7206.6015625
#
# Property Neighborhood: Edwards
# Actual Sale Price: 123000.0
# Predicted Sale Price: 130167.4765625
# Residual: 7167.4765625
#
# Property Neighborhood: BrDale
# Actual Sale Price: 235000.0
# Predicted Sale Price: 241863.265625
# Residual: 6863.265625
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 78000.0
# Predicted Sale Price: 84716.5625
# Residual: 6716.5625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 143000.0
# Predicted Sale Price: 149702.328125
# Residual: 6702.328125
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 143000.0
# Predicted Sale Price: 149702.328125
# Residual: 6702.328125
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 87000.0
# Predicted Sale Price: 93477.375
# Residual: 6477.375
#
# Property Neighborhood: StoneBr
# Actual Sale Price: 181000.0
# Predicted Sale Price: 187419.046875
# Residual: 6419.046875
#
# Property Neighborhood: Timber
# Actual Sale Price: 246500.0
# Predicted Sale Price: 252460.609375
# Residual: 5960.609375
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 145000.0
# Predicted Sale Price: 150954.140625
# Residual: 5954.140625
#
# Property Neighborhood: BrDale
# Actual Sale Price: 144000.0
# Predicted Sale Price: 149953.6875
# Residual: 5953.6875
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 131000.0
# Predicted Sale Price: 136849.609375
# Residual: 5849.609375
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 315000.0
# Predicted Sale Price: 320810.84375
# Residual: 5810.84375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 132500.0
# Predicted Sale Price: 138283.640625
# Residual: 5783.640625
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 246500.0
# Predicted Sale Price: 252281.25
# Residual: 5781.25
#
# Property Neighborhood: Edwards
# Actual Sale Price: 285000.0
# Predicted Sale Price: 290776.4375
# Residual: 5776.4375
#
# Property Neighborhood: Edwards
# Actual Sale Price: 140000.0
# Predicted Sale Price: 145766.96875
# Residual: 5766.96875
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 110000.0
# Predicted Sale Price: 115715.96875
# Residual: 5715.96875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 315000.0
# Predicted Sale Price: 320685.71875
# Residual: 5685.71875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 285000.0
# Predicted Sale Price: 290598.0
# Residual: 5598.0
#
# Property Neighborhood: NAmes
# Actual Sale Price: 156932.0
# Predicted Sale Price: 162515.3125
# Residual: 5583.3125
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 156932.0
# Predicted Sale Price: 162472.5625
# Residual: 5540.5625
#
# Property Neighborhood: Edwards
# Actual Sale Price: 220000.0
# Predicted Sale Price: 225527.46875
# Residual: 5527.46875
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 310000.0
# Predicted Sale Price: 315500.1875
# Residual: 5500.1875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 115500.0
# Predicted Sale Price: 120987.3671875
# Residual: 5487.3671875
#
# Property Neighborhood: Edwards
# Actual Sale Price: 111500.0
# Predicted Sale Price: 116976.984375
# Residual: 5476.984375
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 320000.0
# Predicted Sale Price: 325332.6875
# Residual: 5332.6875
#
# Property Neighborhood: NPkVill
# Actual Sale Price: 296000.0
# Predicted Sale Price: 301317.8125
# Residual: 5317.8125
#
# Property Neighborhood: Edwards
# Actual Sale Price: 142500.0
# Predicted Sale Price: 147649.296875
# Residual: 5149.296875
#
# Property Neighborhood: MeadowV
# Actual Sale Price: 320000.0
# Predicted Sale Price: 325123.59375
# Residual: 5123.59375
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 125500.0
# Predicted Sale Price: 130621.1484375
# Residual: 5121.1484375
#
# Property Neighborhood: Somerst
# Actual Sale Price: 79400.0
# Predicted Sale Price: 84457.203125
# Residual: 5057.203125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 128000.0
# Predicted Sale Price: 132999.65625
# Residual: 4999.65625
#
# Property Neighborhood: StoneBr
# Actual Sale Price: 390000.0
# Predicted Sale Price: 394971.5625
# Residual: 4971.5625
#
# Property Neighborhood: OldTown
# Actual Sale Price: 124000.0
# Predicted Sale Price: 128965.4765625
# Residual: 4965.4765625
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 111500.0
# Predicted Sale Price: 116457.0
# Residual: 4957.0
#
# Property Neighborhood: NAmes
# Actual Sale Price: 230000.0
# Predicted Sale Price: 234910.90625
# Residual: 4910.90625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 230000.0
# Predicted Sale Price: 234910.90625
# Residual: 4910.90625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 180000.0
# Predicted Sale Price: 184879.203125
# Residual: 4879.203125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 214000.0
# Predicted Sale Price: 218863.015625
# Residual: 4863.015625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 93500.0
# Predicted Sale Price: 98336.96875
# Residual: 4836.96875
#
# Property Neighborhood: OldTown
# Actual Sale Price: 91000.0
# Predicted Sale Price: 95815.578125
# Residual: 4815.578125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 113000.0
# Predicted Sale Price: 117785.6640625
# Residual: 4785.6640625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 192500.0
# Predicted Sale Price: 197265.0
# Residual: 4765.0
#
# Property Neighborhood: NAmes
# Actual Sale Price: 296000.0
# Predicted Sale Price: 300760.875
# Residual: 4760.875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 112500.0
# Predicted Sale Price: 117228.1171875
# Residual: 4728.1171875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 123000.0
# Predicted Sale Price: 127699.1484375
# Residual: 4699.1484375
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 140000.0
# Predicted Sale Price: 144677.40625
# Residual: 4677.40625
#
# Property Neighborhood: OldTown
# Actual Sale Price: 178000.0
# Predicted Sale Price: 182581.484375
# Residual: 4581.484375
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 320000.0
# Predicted Sale Price: 324577.375
# Residual: 4577.375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 125000.0
# Predicted Sale Price: 129563.96875
# Residual: 4563.96875
#
# Property Neighborhood: Blueste
# Actual Sale Price: 125000.0
# Predicted Sale Price: 129547.2890625
# Residual: 4547.2890625
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 125000.0
# Predicted Sale Price: 129547.2890625
# Residual: 4547.2890625
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 201000.0
# Predicted Sale Price: 205503.140625
# Residual: 4503.140625
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 140000.0
# Predicted Sale Price: 144501.21875
# Residual: 4501.21875
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 100000.0
# Predicted Sale Price: 104468.1953125
# Residual: 4468.1953125
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 176000.0
# Predicted Sale Price: 180463.796875
# Residual: 4463.796875
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 182000.0
# Predicted Sale Price: 186392.078125
# Residual: 4392.078125
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 149500.0
# Predicted Sale Price: 153880.203125
# Residual: 4380.203125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 120000.0
# Predicted Sale Price: 124371.46875
# Residual: 4371.46875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 188000.0
# Predicted Sale Price: 192332.09375
# Residual: 4332.09375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 155000.0
# Predicted Sale Price: 159313.921875
# Residual: 4313.921875
#
# Property Neighborhood: NoRidge
# Actual Sale Price: 144000.0
# Predicted Sale Price: 148264.09375
# Residual: 4264.09375
#
# Property Neighborhood: Edwards
# Actual Sale Price: 160000.0
# Predicted Sale Price: 164234.5
# Residual: 4234.5
#
# Property Neighborhood: Blueste
# Actual Sale Price: 131400.0
# Predicted Sale Price: 135628.03125
# Residual: 4228.03125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 143500.0
# Predicted Sale Price: 147723.75
# Residual: 4223.75
#
# Property Neighborhood: Edwards
# Actual Sale Price: 160500.0
# Predicted Sale Price: 164632.9375
# Residual: 4132.9375
#
# Property Neighborhood: SWISU
# Actual Sale Price: 170440.0
# Predicted Sale Price: 174562.8125
# Residual: 4122.8125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 124500.0
# Predicted Sale Price: 128610.078125
# Residual: 4110.078125
#
# Property Neighborhood: StoneBr
# Actual Sale Price: 85400.00000000001
# Predicted Sale Price: 89460.6640625
# Residual: 4060.6640624999854
#
# Property Neighborhood: Greens
# Actual Sale Price: 210000.0
# Predicted Sale Price: 214047.0
# Residual: 4047.0
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 200000.0
# Predicted Sale Price: 204042.703125
# Residual: 4042.703125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 173000.0
# Predicted Sale Price: 177034.84375
# Residual: 4034.84375
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 172500.0
# Predicted Sale Price: 176484.71875
# Residual: 3984.71875
#
# Property Neighborhood: StoneBr
# Actual Sale Price: 149500.0
# Predicted Sale Price: 153468.953125
# Residual: 3968.953125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 132000.0
# Predicted Sale Price: 135916.078125
# Residual: 3916.078125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 153000.0
# Predicted Sale Price: 156906.421875
# Residual: 3906.421875
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 184900.0
# Predicted Sale Price: 188772.765625
# Residual: 3872.765625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 131500.0
# Predicted Sale Price: 135354.234375
# Residual: 3854.234375
#
# Property Neighborhood: NridgHt
# Actual Sale Price: 178000.0
# Predicted Sale Price: 181849.796875
# Residual: 3849.796875
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 159500.0
# Predicted Sale Price: 163341.6875
# Residual: 3841.6875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 83000.0
# Predicted Sale Price: 86817.984375
# Residual: 3817.984375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 155000.0
# Predicted Sale Price: 158777.765625
# Residual: 3777.765625
#
# Property Neighborhood: NridgHt
# Actual Sale Price: 89000.0
# Predicted Sale Price: 92753.359375
# Residual: 3753.359375
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 153000.0
# Predicted Sale Price: 156657.265625
# Residual: 3657.265625
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 128000.0
# Predicted Sale Price: 131608.65625
# Residual: 3608.65625
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 160500.0
# Predicted Sale Price: 164101.96875
# Residual: 3601.96875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 167000.0
# Predicted Sale Price: 170590.140625
# Residual: 3590.140625
#
# Property Neighborhood: Edwards
# Actual Sale Price: 89500.0
# Predicted Sale Price: 93073.140625
# Residual: 3573.140625
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 234250.0
# Predicted Sale Price: 237811.53125
# Residual: 3561.53125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 121500.0
# Predicted Sale Price: 125054.25
# Residual: 3554.25
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 89500.0
# Predicted Sale Price: 93020.1484375
# Residual: 3520.1484375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 334000.0
# Predicted Sale Price: 337460.875
# Residual: 3460.875
#
# Property Neighborhood: Edwards
# Actual Sale Price: 193800.0
# Predicted Sale Price: 197216.578125
# Residual: 3416.578125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 145000.0
# Predicted Sale Price: 148413.96875
# Residual: 3413.96875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 91300.0
# Predicted Sale Price: 94691.0859375
# Residual: 3391.0859375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 137000.0
# Predicted Sale Price: 140372.078125
# Residual: 3372.078125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 73000.0
# Predicted Sale Price: 76370.484375
# Residual: 3370.484375
#
# Property Neighborhood: StoneBr
# Actual Sale Price: 176000.0
# Predicted Sale Price: 179349.203125
# Residual: 3349.203125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 125500.0
# Predicted Sale Price: 128839.2578125
# Residual: 3339.2578125
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 160000.0
# Predicted Sale Price: 163339.046875
# Residual: 3339.046875
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 118000.0
# Predicted Sale Price: 121324.8359375
# Residual: 3324.8359375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 143000.0
# Predicted Sale Price: 146317.453125
# Residual: 3317.453125
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 235128.0
# Predicted Sale Price: 238420.59375
# Residual: 3292.59375
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 230500.0
# Predicted Sale Price: 233790.046875
# Residual: 3290.046875
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 230500.0
# Predicted Sale Price: 233790.046875
# Residual: 3290.046875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 145000.0
# Predicted Sale Price: 148280.828125
# Residual: 3280.828125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 167000.0
# Predicted Sale Price: 170230.703125
# Residual: 3230.703125
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 201490.0
# Predicted Sale Price: 204678.328125
# Residual: 3188.328125
#
# Property Neighborhood: Somerst
# Actual Sale Price: 137000.0
# Predicted Sale Price: 140134.40625
# Residual: 3134.40625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 137000.0
# Predicted Sale Price: 140130.4375
# Residual: 3130.4375
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 120000.0
# Predicted Sale Price: 123115.0703125
# Residual: 3115.0703125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 144100.0
# Predicted Sale Price: 147187.46875
# Residual: 3087.46875
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 93000.0
# Predicted Sale Price: 96072.5703125
# Residual: 3072.5703125
#
# Property Neighborhood: MeadowV
# Actual Sale Price: 259500.0
# Predicted Sale Price: 262550.40625
# Residual: 3050.40625
#
# Property Neighborhood: OldTown
# Actual Sale Price: 135960.0
# Predicted Sale Price: 138979.15625
# Residual: 3019.15625
#
# Property Neighborhood: NoRidge
# Actual Sale Price: 134000.0
# Predicted Sale Price: 137004.078125
# Residual: 3004.078125
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 131000.0
# Predicted Sale Price: 134001.078125
# Residual: 3001.078125
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 130000.0
# Predicted Sale Price: 132990.59375
# Residual: 2990.59375
#
# Property Neighborhood: BrDale
# Actual Sale Price: 118000.0
# Predicted Sale Price: 120979.546875
# Residual: 2979.546875
#
# Property Neighborhood: Edwards
# Actual Sale Price: 131000.0
# Predicted Sale Price: 133958.28125
# Residual: 2958.28125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 253293.0
# Predicted Sale Price: 256243.125
# Residual: 2950.125
#
# Property Neighborhood: ClearCr
# Actual Sale Price: 103000.0
# Predicted Sale Price: 105938.7578125
# Residual: 2938.7578125
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 112000.0
# Predicted Sale Price: 114850.46875
# Residual: 2850.46875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 104900.0
# Predicted Sale Price: 107748.0546875
# Residual: 2848.0546875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 251000.0
# Predicted Sale Price: 253802.859375
# Residual: 2802.859375
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 173500.0
# Predicted Sale Price: 176272.65625
# Residual: 2772.65625
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 118000.0
# Predicted Sale Price: 120737.125
# Residual: 2737.125
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 138000.0
# Predicted Sale Price: 140725.34375
# Residual: 2725.34375
#
# Property Neighborhood: Edwards
# Actual Sale Price: 133500.0
# Predicted Sale Price: 136151.578125
# Residual: 2651.578125
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 114000.0
# Predicted Sale Price: 116642.2109375
# Residual: 2642.2109375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 124000.0
# Predicted Sale Price: 126587.1015625
# Residual: 2587.1015625
#
# Property Neighborhood: ClearCr
# Actual Sale Price: 215000.0
# Predicted Sale Price: 217577.921875
# Residual: 2577.921875
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 128500.0
# Predicted Sale Price: 131065.1484375
# Residual: 2565.1484375
#
# Property Neighborhood: NPkVill
# Actual Sale Price: 126000.0
# Predicted Sale Price: 128542.5703125
# Residual: 2542.5703125
#
# Property Neighborhood: NPkVill
# Actual Sale Price: 315000.0
# Predicted Sale Price: 317533.71875
# Residual: 2533.71875
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 184900.0
# Predicted Sale Price: 187429.390625
# Residual: 2529.390625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 107000.0
# Predicted Sale Price: 109525.796875
# Residual: 2525.796875
#
# Property Neighborhood: ClearCr
# Actual Sale Price: 335000.0
# Predicted Sale Price: 337524.0625
# Residual: 2524.0625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 128000.0
# Predicted Sale Price: 130508.640625
# Residual: 2508.640625
#
# Property Neighborhood: Edwards
# Actual Sale Price: 174000.0
# Predicted Sale Price: 176472.640625
# Residual: 2472.640625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 151000.0
# Predicted Sale Price: 153467.296875
# Residual: 2467.296875
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 240000.0
# Predicted Sale Price: 242456.90625
# Residual: 2456.90625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 325000.0
# Predicted Sale Price: 327441.3125
# Residual: 2441.3125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 88000.0
# Predicted Sale Price: 90422.3671875
# Residual: 2422.3671875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 170440.0
# Predicted Sale Price: 172832.4375
# Residual: 2392.4375
#
# Property Neighborhood: BrDale
# Actual Sale Price: 217000.0
# Predicted Sale Price: 219369.703125
# Residual: 2369.703125
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 149900.0
# Predicted Sale Price: 152263.390625
# Residual: 2363.390625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 212700.0
# Predicted Sale Price: 215056.921875
# Residual: 2356.921875
#
# Property Neighborhood: SWISU
# Actual Sale Price: 132500.0
# Predicted Sale Price: 134750.15625
# Residual: 2250.15625
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 325000.0
# Predicted Sale Price: 327199.125
# Residual: 2199.125
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 110000.0
# Predicted Sale Price: 112185.3828125
# Residual: 2185.3828125
#
# Property Neighborhood: Edwards
# Actual Sale Price: 170000.0
# Predicted Sale Price: 172181.59375
# Residual: 2181.59375
#
# Property Neighborhood: BrDale
# Actual Sale Price: 205000.0
# Predicted Sale Price: 207174.25
# Residual: 2174.25
#
# Property Neighborhood: NAmes
# Actual Sale Price: 102000.0
# Predicted Sale Price: 104148.0234375
# Residual: 2148.0234375
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 148000.0
# Predicted Sale Price: 150137.828125
# Residual: 2137.828125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 64000.0
# Predicted Sale Price: 66065.6328125
# Residual: 2065.6328125
#
# Property Neighborhood: StoneBr
# Actual Sale Price: 122250.0
# Predicted Sale Price: 124313.1328125
# Residual: 2063.1328125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 189000.0
# Predicted Sale Price: 191060.921875
# Residual: 2060.921875
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 380000.0
# Predicted Sale Price: 382045.28125
# Residual: 2045.28125
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 170440.0
# Predicted Sale Price: 172475.765625
# Residual: 2035.765625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 102000.0
# Predicted Sale Price: 104020.421875
# Residual: 2020.421875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 162000.0
# Predicted Sale Price: 164016.671875
# Residual: 2016.671875
#
# Property Neighborhood: OldTown
# Actual Sale Price: 131750.0
# Predicted Sale Price: 133764.3125
# Residual: 2014.3125
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 236500.0
# Predicted Sale Price: 238482.34375
# Residual: 1982.34375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 149900.0
# Predicted Sale Price: 151838.640625
# Residual: 1938.640625
#
# Property Neighborhood: OldTown
# Actual Sale Price: 145000.0
# Predicted Sale Price: 146886.765625
# Residual: 1886.765625
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 174000.0
# Predicted Sale Price: 175883.859375
# Residual: 1883.859375
#
# Property Neighborhood: SWISU
# Actual Sale Price: 128500.0
# Predicted Sale Price: 130364.84375
# Residual: 1864.84375
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 210000.0
# Predicted Sale Price: 211839.453125
# Residual: 1839.453125
#
# Property Neighborhood: NridgHt
# Actual Sale Price: 137000.0
# Predicted Sale Price: 138826.5
# Residual: 1826.5
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 64000.0
# Predicted Sale Price: 65823.4140625
# Residual: 1823.4140625
#
# Property Neighborhood: NoRidge
# Actual Sale Price: 204000.0
# Predicted Sale Price: 205819.96875
# Residual: 1819.96875
#
# Property Neighborhood: Somerst
# Actual Sale Price: 190000.0
# Predicted Sale Price: 191776.28125
# Residual: 1776.28125
#
# Property Neighborhood: NAmes
# Actual Sale Price: 220000.0
# Predicted Sale Price: 221724.921875
# Residual: 1724.921875
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 419005.0
# Predicted Sale Price: 420674.78125
# Residual: 1669.78125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 72000.0
# Predicted Sale Price: 73650.4453125
# Residual: 1650.4453125
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 369900.0
# Predicted Sale Price: 371549.96875
# Residual: 1649.96875
#
# Property Neighborhood: OldTown
# Actual Sale Price: 148000.0
# Predicted Sale Price: 149617.46875
# Residual: 1617.46875
#
# Property Neighborhood: OldTown
# Actual Sale Price: 151500.0
# Predicted Sale Price: 153098.625
# Residual: 1598.625
#
# Property Neighborhood: Edwards
# Actual Sale Price: 213000.0
# Predicted Sale Price: 214579.21875
# Residual: 1579.21875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 187100.0
# Predicted Sale Price: 188638.015625
# Residual: 1538.015625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 250000.0
# Predicted Sale Price: 251536.390625
# Residual: 1536.390625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 417500.0
# Predicted Sale Price: 419020.4375
# Residual: 1520.4375
#
# Property Neighborhood: OldTown
# Actual Sale Price: 68500.0
# Predicted Sale Price: 70016.7109375
# Residual: 1516.7109375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 120500.0
# Predicted Sale Price: 121984.265625
# Residual: 1484.265625
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 228000.0
# Predicted Sale Price: 229476.59375
# Residual: 1476.59375
#
# Property Neighborhood: SWISU
# Actual Sale Price: 134900.0
# Predicted Sale Price: 136344.6875
# Residual: 1444.6875
#
# Property Neighborhood: StoneBr
# Actual Sale Price: 155000.0
# Predicted Sale Price: 156436.484375
# Residual: 1436.484375
#
# Property Neighborhood: Timber
# Actual Sale Price: 127000.0
# Predicted Sale Price: 128429.0703125
# Residual: 1429.0703125
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 129250.0
# Predicted Sale Price: 130666.953125
# Residual: 1416.953125
#
# Property Neighborhood: NridgHt
# Actual Sale Price: 133900.0
# Predicted Sale Price: 135316.71875
# Residual: 1416.71875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 174000.0
# Predicted Sale Price: 175390.828125
# Residual: 1390.828125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 310000.0
# Predicted Sale Price: 311389.4375
# Residual: 1389.4375
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 189000.0
# Predicted Sale Price: 190382.171875
# Residual: 1382.171875
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 127000.0
# Predicted Sale Price: 128379.5859375
# Residual: 1379.5859375
#
# Property Neighborhood: ClearCr
# Actual Sale Price: 139500.0
# Predicted Sale Price: 140864.984375
# Residual: 1364.984375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 318000.0
# Predicted Sale Price: 319338.84375
# Residual: 1338.84375
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 129200.0
# Predicted Sale Price: 130537.5390625
# Residual: 1337.5390625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 139500.0
# Predicted Sale Price: 140813.34375
# Residual: 1313.34375
#
# Property Neighborhood: OldTown
# Actual Sale Price: 131000.0
# Predicted Sale Price: 132262.78125
# Residual: 1262.78125
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 128900.0
# Predicted Sale Price: 130137.328125
# Residual: 1237.328125
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 475000.0
# Predicted Sale Price: 476167.90625
# Residual: 1167.90625
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 270000.0
# Predicted Sale Price: 271148.21875
# Residual: 1148.21875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 150000.0
# Predicted Sale Price: 151123.84375
# Residual: 1123.84375
#
# Property Neighborhood: OldTown
# Actual Sale Price: 167000.0
# Predicted Sale Price: 168096.1875
# Residual: 1096.1875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 419005.0
# Predicted Sale Price: 420094.21875
# Residual: 1089.21875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 130000.0
# Predicted Sale Price: 131082.8125
# Residual: 1082.8125
#
# Property Neighborhood: Edwards
# Actual Sale Price: 263000.0
# Predicted Sale Price: 264073.5
# Residual: 1073.5
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 213000.0
# Predicted Sale Price: 214051.6875
# Residual: 1051.6875
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 115000.0
# Predicted Sale Price: 116043.6484375
# Residual: 1043.6484375
#
# Property Neighborhood: Edwards
# Actual Sale Price: 135000.0
# Predicted Sale Price: 136043.25
# Residual: 1043.25
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 160500.0
# Predicted Sale Price: 161524.421875
# Residual: 1024.421875
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 243500.0
# Predicted Sale Price: 244520.640625
# Residual: 1020.640625
#
# Property Neighborhood: Timber
# Actual Sale Price: 148500.0
# Predicted Sale Price: 149509.5
# Residual: 1009.5
#
# Property Neighborhood: NAmes
# Actual Sale Price: 125500.0
# Predicted Sale Price: 126505.75
# Residual: 1005.75
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 128000.0
# Predicted Sale Price: 128990.9140625
# Residual: 990.9140625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 129200.0
# Predicted Sale Price: 130187.96875
# Residual: 987.96875
#
# Property Neighborhood: Edwards
# Actual Sale Price: 155000.0
# Predicted Sale Price: 155976.46875
# Residual: 976.46875
#
# Property Neighborhood: Edwards
# Actual Sale Price: 155000.0
# Predicted Sale Price: 155976.46875
# Residual: 976.46875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 336860.0
# Predicted Sale Price: 337825.6875
# Residual: 965.6875
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 142900.0
# Predicted Sale Price: 143865.125
# Residual: 965.125
#
# Property Neighborhood: Edwards
# Actual Sale Price: 219500.0
# Predicted Sale Price: 220460.578125
# Residual: 960.578125
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 99000.0
# Predicted Sale Price: 99940.5390625
# Residual: 940.5390625
#
# Property Neighborhood: NridgHt
# Actual Sale Price: 98000.0
# Predicted Sale Price: 98935.3515625
# Residual: 935.3515625
#
# Property Neighborhood: OldTown
# Actual Sale Price: 92900.0
# Predicted Sale Price: 93817.515625
# Residual: 917.515625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 187500.0
# Predicted Sale Price: 188398.8125
# Residual: 898.8125
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 190000.0
# Predicted Sale Price: 190887.4375
# Residual: 887.4375
#
# Property Neighborhood: NoRidge
# Actual Sale Price: 190000.0
# Predicted Sale Price: 190877.859375
# Residual: 877.859375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 215200.0
# Predicted Sale Price: 216057.671875
# Residual: 857.671875
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 170000.0
# Predicted Sale Price: 170825.0625
# Residual: 825.0625
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 290000.0
# Predicted Sale Price: 290823.78125
# Residual: 823.78125
#
# Property Neighborhood: Timber
# Actual Sale Price: 152000.0
# Predicted Sale Price: 152821.875
# Residual: 821.875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 153000.0
# Predicted Sale Price: 153805.390625
# Residual: 805.390625
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 224500.0
# Predicted Sale Price: 225286.421875
# Residual: 786.421875
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 270000.0
# Predicted Sale Price: 270742.28125
# Residual: 742.28125
#
# Property Neighborhood: IDOTRR
# Actual Sale Price: 78999.99999999999
# Predicted Sale Price: 79686.8203125
# Residual: 686.8203125000146
#
# Property Neighborhood: Gilbert
# Actual Sale Price: 127000.0
# Predicted Sale Price: 127685.3359375
# Residual: 685.3359375
#
# Property Neighborhood: SWISU
# Actual Sale Price: 132500.0
# Predicted Sale Price: 133170.53125
# Residual: 670.53125
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 127000.0
# Predicted Sale Price: 127649.3515625
# Residual: 649.3515625
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 260000.0
# Predicted Sale Price: 260634.5
# Residual: 634.5
#
# Property Neighborhood: NAmes
# Actual Sale Price: 100500.0
# Predicted Sale Price: 101110.671875
# Residual: 610.671875
#
# Property Neighborhood: BrDale
# Actual Sale Price: 130000.0
# Predicted Sale Price: 130600.296875
# Residual: 600.296875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 158000.0
# Predicted Sale Price: 158581.15625
# Residual: 581.15625
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 181000.0
# Predicted Sale Price: 181513.03125
# Residual: 513.03125
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 181000.0
# Predicted Sale Price: 181513.03125
# Residual: 513.03125
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 135000.0
# Predicted Sale Price: 135504.65625
# Residual: 504.65625
#
# Property Neighborhood: NridgHt
# Actual Sale Price: 158000.0
# Predicted Sale Price: 158493.6875
# Residual: 493.6875
#
# Property Neighborhood: Somerst
# Actual Sale Price: 214000.0
# Predicted Sale Price: 214472.09375
# Residual: 472.09375
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 131750.0
# Predicted Sale Price: 132216.984375
# Residual: 466.984375
#
# Property Neighborhood: Edwards
# Actual Sale Price: 245000.0
# Predicted Sale Price: 245460.921875
# Residual: 460.921875
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 226001.0
# Predicted Sale Price: 226430.46875
# Residual: 429.46875
#
# Property Neighborhood: Sawyer
# Actual Sale Price: 215000.0
# Predicted Sale Price: 215426.53125
# Residual: 426.53125
#
# Property Neighborhood: NWAmes
# Actual Sale Price: 128500.0
# Predicted Sale Price: 128885.8671875
# Residual: 385.8671875
#
# Property Neighborhood: Somerst
# Actual Sale Price: 122000.0
# Predicted Sale Price: 122366.2890625
# Residual: 366.2890625
#
# Property Neighborhood: BrkSide
# Actual Sale Price: 185101.0
# Predicted Sale Price: 185443.46875
# Residual: 342.46875
#
# Property Neighborhood: Crawfor
# Actual Sale Price: 119000.0
# Predicted Sale Price: 119299.6015625
# Residual: 299.6015625
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 55000.0
# Predicted Sale Price: 55275.3046875
# Residual: 275.3046875
#
# Property Neighborhood: Timber
# Actual Sale Price: 120000.0
# Predicted Sale Price: 120260.078125
# Residual: 260.078125
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 168000.0
# Predicted Sale Price: 168208.484375
# Residual: 208.484375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 255000.0
# Predicted Sale Price: 255207.8125
# Residual: 207.8125
#
# Property Neighborhood: SawyerW
# Actual Sale Price: 118900.0
# Predicted Sale Price: 119084.953125
# Residual: 184.953125
#
# Property Neighborhood: OldTown
# Actual Sale Price: 179000.0
# Predicted Sale Price: 179176.828125
# Residual: 176.828125
#
# Property Neighborhood: Edwards
# Actual Sale Price: 198900.0
# Predicted Sale Price: 199068.609375
# Residual: 168.609375
#
# Property Neighborhood: Edwards
# Actual Sale Price: 222000.0
# Predicted Sale Price: 222153.203125
# Residual: 153.203125
#
# Property Neighborhood: MeadowV
# Actual Sale Price: 75500.0
# Predicted Sale Price: 75646.90625
# Residual: 146.90625
#
# Property Neighborhood: NAmes
# Actual Sale Price: 80000.00000000001
# Predicted Sale Price: 80136.9375
# Residual: 136.93749999998545
#
# Property Neighborhood: Edwards
# Actual Sale Price: 132000.0
# Predicted Sale Price: 132122.09375
# Residual: 122.09375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 214000.0
# Predicted Sale Price: 214106.984375
# Residual: 106.984375
#
# Property Neighborhood: NoRidge
# Actual Sale Price: 378500.0
# Predicted Sale Price: 378602.34375
# Residual: 102.34375
#
# Property Neighborhood: Mitchel
# Actual Sale Price: 187500.0
# Predicted Sale Price: 187594.046875
# Residual: 94.046875
#
# Property Neighborhood: Somerst
# Actual Sale Price: 136500.0
# Predicted Sale Price: 136585.609375
# Residual: 85.609375
#
# Property Neighborhood: NAmes
# Actual Sale Price: 130000.0
# Predicted Sale Price: 130043.75
# Residual: 43.75
#
# Property Neighborhood: BrDale
# Actual Sale Price: 118500.0
# Predicted Sale Price: 118540.1484375
# Residual: 40.1484375
#
# Property Neighborhood: CollgCr
# Actual Sale Price: 222000.0
# Predicted Sale Price: 222035.375
# Residual: 35.375
#
# Property Neighborhood: Timber
# Actual Sale Price: 196000.0
# Predicted Sale Price: 196017.421875
# Residual: 17.421875
#
# Property Neighborhood: NAmes
# Actual Sale Price: 119000.0
# Predicted Sale Price: 119008.1953125
# Residual: 8.1953125
#
# Property Neighborhood: ClearCr
# Actual Sale Price: 215000.0
# Predicted Sale Price: 215001.78125
# Residual: 1.78125

# %%
# Filter undervalued properties
undervalued_properties = residuals_df[residuals_df['Actual Sale Price'] < residuals_df['Predicted Sale Price']].sort_values(by='Residuals', ascending=False)

# Count the number of undervalued properties
num_undervalued_properties = len(undervalued_properties)

# Print the count
print("Number of Undervalued Properties:", num_undervalued_properties)
# Out:
# Number of Undervalued Properties: 390

# %%
undervalued_properties
# Out:
#       Actual Sale Price  Predicted Sale Price     Residuals Neighborhood
# 2402           260116.0         327122.562500  67006.562500      Somerst
# 2427           327000.0         392312.187500  65312.187500       Timber
# 2424           110000.0         146002.093750  36002.093750      Gilbert
# 826            221300.0         255930.515625  34630.515625      OldTown
# 827            221300.0         255460.656250  34160.656250      Edwards
# ...                 ...                   ...           ...          ...
# 1087           118500.0         118540.148438     40.148438       BrDale
# 184            222000.0         222035.375000     35.375000      CollgCr
# 105            196000.0         196017.421875     17.421875       Timber
# 1092           119000.0         119008.195312      8.195312        NAmes
# 1034           215000.0         215001.781250      1.781250      ClearCr
#
# [390 rows x 4 columns]
